# %%
import pandas as pd
import numpy as np
import datetime

import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib.image as mpimg
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#store the path of your directory in a var
path ='C:\\Users\\afayyaz\\Desktop\\Projects\\Predicting\\'

# %% [markdown]
# ### Import the DOB Now dataset

# %%
DOB_now_permits_df = pd.read_csv(path + "DOBNOW job_permits high risk construction.csv")
DOB_now_permits_df.head()
# Out:
#        Bin House Number   Street Name  Community Board    Job Number  \
# 0  1000000          451     10 AVENUE              NaN  M00532013-I1
# 1  1000000          451     10 AVENUE              NaN  M00532013-I1
# 2  1000003           10  SOUTH STREET            101.0  M00027908-I1
# 3  1000003           10  SOUTH STREET            101.0  M00027908-I1
# 4  1000003           10  SOUTH STREET            101.0  M00027908-I1
#
#   Applicant Business Name     JobType    Borough  ProposedBuildingHeight  \
# 0   HANDEL ARCHITECTS LLP  Alteration  MANHATTAN                   541.0
# 1   HANDEL ARCHITECTS LLP  Alteration  MANHATTAN                   541.0
# 2      TOHFAZ UDDIN PE PC  Alteration  MANHATTAN                     NaN
# 3      TOHFAZ UDDIN PE PC  Alteration  MANHATTAN                     NaN
# 4      TOHFAZ UDDIN PE PC  Alteration  MANHATTAN                     NaN
#
#    ProposeeBuildingStoriesft   Permit Issued Date Permit Expiration Date  \
# 0                       44.0  2021-08-12 00:00:00    2021-12-01 05:00:00
# 1                       44.0  2021-12-06 00:00:00    2022-08-28 00:00:00
# 2                        NaN  2018-03-21 00:00:00    2018-10-01 00:00:00
# 3                        NaN  2018-10-05 00:00:00    2019-10-01 00:00:00
# 4                        NaN  2019-10-10 00:00:00    2020-10-01 00:00:00
#
#          Work Type Name   Proposed Occupancy Classification  \
# 0  General Construction  R-2-Residential (Apartment Houses)
# 1  General Construction  R-2-Residential (Apartment Houses)
# 2         Sidewalk Shed                                 NaN
# 3         Sidewalk Shed                                 NaN
# 4         Sidewalk Shed                                 NaN
#
#    Proposed Dwelling Units
# 0                    532.0
# 1                    532.0
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %% [markdown]
# ### Cleaning the DOB Now dataset

# %%
# Rename the Applicant Business Name to Contractor Name
DOB_now_permits_df = DOB_now_permits_df.rename(columns={'Applicant Business Name': 'Contractor Name',
                                                         'Work Type Name' : 'Permit Sub Type'},)

#Create a Permit Type Column
DOB_now_permits_df["Permit Type"] = "EQ"

# %% [markdown]
# ### Check the value counts of unique work type names and change them to codes instead

# %%
DOB_now_permits_df["Permit Sub Type"].value_counts()
# Out:
# Sidewalk Shed                        47729
# Plumbing                             45918
# Construction Fence                   37788
# General Construction                 26780
# Supported Scaffold                   24041
# Mechanical Systems                   22990
# Sprinklers                           15119
# Sign                                 14020
# Structural                            8149
# Boiler Equipment                      3953
# Antenna                               3764
# Curb Cut                              3216
# Standpipe                             2485
# Protection and Mechanical Methods     1743
# Foundation                            1520
# Earth Work                             898
# Support of Excavation                  412
# Name: Permit Sub Type, dtype: int64

# %%
#Use the codes for Work Type Names

DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Sidewalk Shed','SH')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Plumbing','PL')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Construction Fence','FN')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('General Construction','GC')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Supported Scaffold','SF')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Mechanical Systems','MS')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Sprinklers','SP')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Sign','SG')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Structural','ST')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Boiler Equipment','BE')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Antenna','AN')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Curb Cut','CC')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Standpipe','SD')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Protection and Mechanical Methods','PM')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Foundation','FO')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Earth Work','EA')
DOB_now_permits_df["Permit Sub Type"] = DOB_now_permits_df["Permit Sub Type"].str.replace('Support of Excavation','SE')

# DOB_now_permits_df.head()

# %% [markdown]
# ### Importing the BIS dataset

# %%
BIS_job_permits_df = pd.read_csv(path + "BIS jobs_permits construction high risk.csv")
BIS_job_permits_df.head()
# Out:
#    Job Number Job Type  BIN Number Borough Name  Community Board  \
# 0   100039995       A2     1048918    Manhattan            108.0
# 1   100039995       A2     1048918    Manhattan            108.0
# 2   100039995       A2     1048918    Manhattan            108.0
# 3   100039995       A2     1048918    Manhattan            108.0
# 4   100039995       A2     1048918    Manhattan            108.0
#
#   Job Location House Number Job Location Street Name  \
# 0                       245         EAST   93 STREET
# 1                       245         EAST   93 STREET
# 2                       245         EAST   93 STREET
# 3                       245         EAST   93 STREET
# 4                       245         EAST   93 STREET
#
#          Applicant Business Name Permit Type Permit Sub Type  \
# 0  ANTHONY MORALI ARCHITECT PLLC          EW              OT
# 1  ANTHONY MORALI ARCHITECT PLLC          PL             NaN
# 2  ANTHONY MORALI ARCHITECT PLLC          PL             NaN
# 3        ROBERT STRONG ARCHITECT          EW              OT
# 4        ROBERT STRONG ARCHITECT          PL             NaN
#
#    Number of Stories  Proposed Stories  Proposed Height  \
# 0                  0                33              350
# 1                  0                33              350
# 2                  0                33              350
# 3                  0                33              350
# 4                  0                33              350
#
#   Proposed Occupancy Classification Description  Proposed Dwelling Units  \
# 0                                           NaN                    286.0
# 1                                           NaN                    286.0
# 2                                           NaN                    286.0
# 3                                           NaN                    286.0
# 4                                           NaN                    286.0
#
#        D_DATE    D_DATE.1
# 0  2019-09-24  2020-12-31
# 1  2019-09-24  2020-09-23
# 2  2022-02-03  2023-02-03
# 3  2019-09-24  2020-12-31
# 4  2019-09-24  2020-09-23

# %% [markdown]
# ### Compare the column names for both the dataset prior to their concatenation

# %%
print(list(DOB_now_permits_df.columns))
print("\n")
print(list(BIS_job_permits_df.columns))
# Out:
# ['Bin', 'House Number', 'Street Name', 'Community Board', 'Job Number', 'Contractor Name', 'JobType', 'Borough', 'ProposedBuildingHeight', 'ProposeeBuildingStoriesft', 'Permit Issued Date', 'Permit Expiration Date', 'Permit Sub Type', 'Proposed Occupancy Classification', 'Proposed Dwelling Units', 'Permit Type']
#
#
# ['Job Number', 'Job Type', 'BIN Number', 'Borough Name', 'Community Board', 'Job Location House Number', 'Job Location Street Name', 'Applicant Business Name', 'Permit Type', 'Permit Sub Type', 'Number of Stories', 'Proposed Stories', 'Proposed Height', 'Proposed Occupancy Classification Description', 'Proposed Dwelling Units', 'D_DATE', 'D_DATE.1']

# %% [markdown]
# ### Cleaning the BIS dataset

# %%
# Rename all cols to match DOB Now dataset

BIS_job_permits_df = BIS_job_permits_df.rename(columns={'Job Type': 'JobType',
                                                        'BIN Number': 'Bin',
                                                        'Borough Name': 'Borough',
                                                        'Job Location House Number': 'House Number',
                                                        'Job Location Street Name': 'Street Name',
                                                        'Applicant Business Name': 'Contractor Name',
                                                        'Proposed Stories': 'ProposeeBuildingStoriesft',
                                                        'Proposed Height': 'ProposedBuildingHeight',
                                                        'Proposed Occupancy Classification Description': 'Proposed Occupancy Classification',
                                                        'D_DATE': 'Permit Issued Date',
                                                        'D_DATE.1': 'Permit Expiration Date',        
                                                        }
                                               ,)

BIS_job_permits_df = BIS_job_permits_df.drop(['Number of Stories'], axis=1)
BIS_job_permits_df.head()
# Out:
#    Job Number JobType      Bin    Borough  Community Board House Number  \
# 0   100039995      A2  1048918  Manhattan            108.0          245
# 1   100039995      A2  1048918  Manhattan            108.0          245
# 2   100039995      A2  1048918  Manhattan            108.0          245
# 3   100039995      A2  1048918  Manhattan            108.0          245
# 4   100039995      A2  1048918  Manhattan            108.0          245
#
#         Street Name                Contractor Name Permit Type  \
# 0  EAST   93 STREET  ANTHONY MORALI ARCHITECT PLLC          EW
# 1  EAST   93 STREET  ANTHONY MORALI ARCHITECT PLLC          PL
# 2  EAST   93 STREET  ANTHONY MORALI ARCHITECT PLLC          PL
# 3  EAST   93 STREET        ROBERT STRONG ARCHITECT          EW
# 4  EAST   93 STREET        ROBERT STRONG ARCHITECT          PL
#
#   Permit Sub Type  ProposeeBuildingStoriesft  ProposedBuildingHeight  \
# 0              OT                         33                     350
# 1             NaN                         33                     350
# 2             NaN                         33                     350
# 3              OT                         33                     350
# 4             NaN                         33                     350
#
#   Proposed Occupancy Classification  Proposed Dwelling Units  \
# 0                               NaN                    286.0
# 1                               NaN                    286.0
# 2                               NaN                    286.0
# 3                               NaN                    286.0
# 4                               NaN                    286.0
#
#   Permit Issued Date Permit Expiration Date
# 0         2019-09-24             2020-12-31
# 1         2019-09-24             2020-09-23
# 2         2022-02-03             2023-02-03
# 3         2019-09-24             2020-12-31
# 4         2019-09-24             2020-09-23

# %%
# Check the length of two datasets
print("BIS Dataset Length: ", len(BIS_job_permits_df))
print("DOB NOW Dataset Length: ", len(DOB_now_permits_df))
print("Total Length:", len(BIS_job_permits_df) + len(DOB_now_permits_df))
# Out:
# BIS Dataset Length:  850000
# DOB NOW Dataset Length:  260526
# Total Length: 1110526

# %%
#Check the unique Job Numbers in DOB NOW
DOB_now_permits_df["Job Number"].nunique()
# Out:
# 169290

# %% [markdown]
# ### Concatenate the BIS and DOB NOW dataset

# %%
# Concatenate BIS and DOB NOW dataset

frames=[BIS_job_permits_df,DOB_now_permits_df]
permits_df= pd.concat(frames)
display(permits_df.head(5))
display(permits_df.tail(5))
# Out:
#   Job Number JobType      Bin    Borough  Community Board House Number  \
# 0  100039995      A2  1048918  Manhattan            108.0          245
# 1  100039995      A2  1048918  Manhattan            108.0          245
# 2  100039995      A2  1048918  Manhattan            108.0          245
# 3  100039995      A2  1048918  Manhattan            108.0          245
# 4  100039995      A2  1048918  Manhattan            108.0          245
#
#         Street Name                Contractor Name Permit Type  \
# 0  EAST   93 STREET  ANTHONY MORALI ARCHITECT PLLC          EW
# 1  EAST   93 STREET  ANTHONY MORALI ARCHITECT PLLC          PL
# 2  EAST   93 STREET  ANTHONY MORALI ARCHITECT PLLC          PL
# 3  EAST   93 STREET        ROBERT STRONG ARCHITECT          EW
# 4  EAST   93 STREET        ROBERT STRONG ARCHITECT          PL
#
#   Permit Sub Type  ProposeeBuildingStoriesft  ProposedBuildingHeight  \
# 0              OT                       33.0                   350.0
# 1             NaN                       33.0                   350.0
# 2             NaN                       33.0                   350.0
# 3              OT                       33.0                   350.0
# 4             NaN                       33.0                   350.0
#
#   Proposed Occupancy Classification  Proposed Dwelling Units  \
# 0                               NaN                    286.0
# 1                               NaN                    286.0
# 2                               NaN                    286.0
# 3                               NaN                    286.0
# 4                               NaN                    286.0
#
#   Permit Issued Date Permit Expiration Date
# 0         2019-09-24             2020-12-31
# 1         2019-09-24             2020-09-23
# 2         2022-02-03             2023-02-03
# 3         2019-09-24             2020-12-31
# 4         2019-09-24             2020-09-23
#           Job Number                                        JobType      Bin  \
# 260521  S00477364-S1  New Building with Existing Elements to Remain  5868475
# 260522  S00477364-S1  New Building with Existing Elements to Remain  5868475
# 260523  S00520729-I1                                     Alteration  5868475
# 260524  S00520856-I1                                     Alteration  5868475
# 260525  S00520908-I1                                     Alteration  5868475
#
#               Borough  Community Board House Number Street Name  \
# 260521  STATEN ISLAND            501.0            1   DEP PLAZA
# 260522  STATEN ISLAND            501.0            1   DEP PLAZA
# 260523  STATEN ISLAND            501.0            1   DEP PLAZA
# 260524  STATEN ISLAND            501.0            1   DEP PLAZA
# 260525  STATEN ISLAND            501.0            1   DEP PLAZA
#
#        Contractor Name Permit Type Permit Sub Type  ProposeeBuildingStoriesft  \
# 260521            QAZ2          EQ              GC                        1.0
# 260522            QAZ2          EQ              MS                        1.0
# 260523            QAZ2          EQ              GC                      100.0
# 260524            QAZ2          EQ              PM                        NaN
# 260525            QAZ2          EQ              FO                        NaN
#
#         ProposedBuildingHeight Proposed Occupancy Classification  \
# 260521                     1.0                     A-High Hazard
# 260522                     1.0                     A-High Hazard
# 260523                   100.0                       G-Education
# 260524                     NaN                               NaN
# 260525                     NaN          H-4-High Hazard (Health)
#
#         Proposed Dwelling Units   Permit Issued Date Permit Expiration Date
# 260521                      1.0  2021-02-27 00:00:00    2022-02-27 05:00:00
# 260522                      1.0  2021-02-27 00:00:00    2022-02-27 05:00:00
# 260523                    120.0  2021-05-14 00:00:00    2022-05-14 00:00:00
# 260524                     13.0  2021-05-12 00:00:00    2022-05-12 00:00:00
# 260525                     12.0  2021-05-12 00:00:00    2022-05-12 00:00:00

# %%
permits_df.to_csv(path + "permits_df.csv", index=0)

# %%
permits_df.groupby(['Bin'], as_index=False).count()
# Out:
#             Bin  Job Number  JobType  Borough  Community Board  House Number  \
# 0       1000000           2        2        2                0             2
# 1       1000003          64       64       64               64            64
# 2       1000005         361      361      361              361           361
# 3       1000006         137      137      137              137           137
# 4       1000007          92       92       92               92            92
# ...         ...         ...      ...      ...              ...           ...
# 129677  5868168           1        1        1                1             1
# 129678  5868253           1        1        1                1             1
# 129679  5868399           1        1        1                1             1
# 129680  5868411           1        1        1                1             1
# 129681  5868475          13       13       13               13            13
#
#         Street Name  Contractor Name  Permit Type  Permit Sub Type  \
# 0                 2                2            2                2
# 1                64               64           64               37
# 2               361              361          361              317
# 3               137              137          137              127
# 4                92               92           92               76
# ...             ...              ...          ...              ...
# 129677            1                1            1                1
# 129678            1                1            1                1
# 129679            1                1            1                1
# 129680            1                1            1                1
# 129681           13               12           13               13
#
#         ProposeeBuildingStoriesft  ProposedBuildingHeight  \
# 0                               2                       2
# 1                              49                      49
# 2                             290                     289
# 3                             115                     113
# 4                              92                      90
# ...                           ...                     ...
# 129677                          0                       0
# 129678                          0                       0
# 129679                          0                       0
# 129680                          0                       0
# 129681                         10                       5
#
#         Proposed Occupancy Classification  Proposed Dwelling Units  \
# 0                                       2                        2
# 1                                      36                       32
# 2                                     258                       87
# 3                                      95                       39
# 4                                      67                        5
# ...                                   ...                      ...
# 129677                                  0                        0
# 129678                                  0                        1
# 129679                                  0                        1
# 129680                                  0                        1
# 129681                                 12                       13
#
#         Permit Issued Date  Permit Expiration Date
# 0                        2                       2
# 1                       64                      64
# 2                      361                     361
# 3                      137                     137
# 4                       92                      92
# ...                    ...                     ...
# 129677                   1                       1
# 129678                   1                       1
# 129679                   1                       1
# 129680                   1                       1
# 129681                  13                      13
#
# [129682 rows x 16 columns]

# %% [markdown]
# ### Import Incidents dataset

# %%
incidents_df = pd.read_csv(path+ "Incidents-Accidents Data (since 1_1_07) _ TABLEAU.csv")
incidents_df.head()
# Out:
#    Report ID  Year Incident date (MM/DD/YYYY) Time (HH:MM_AM or PM) Check2  \
# 0      20909  2016        2016-01-04 00:00:00   1899-12-30 10:20:00     OC
# 1      20921  2016        2016-01-05 00:00:00   1899-12-30 16:20:00     WF
# 2      20927  2016        2016-01-07 00:00:00   1899-12-30 08:30:00     MF
# 3      20933  2016        2016-01-07 00:00:00   1899-12-30 13:21:00     OC
# 4      20936  2016        2016-01-07 00:00:00   1899-12-30 18:00:00     MF
#
#                 Incident Type                    CR  Fatality  Injury  \
# 0  Other Construction Related  Construction Related         0       1
# 1                 Worker Fell  Construction Related         0       1
# 2     Material Failure (Fell)  Construction Related         0       1
# 3  Other Construction Related  Construction Related         0       1
# 4     Material Failure (Fell)  Construction Related         0       1
#
#    Accident  ... Disposition Incident Level DOB Violation Numbers  \
# 0         1  ...         NaN              1                   NaN
# 1         1  ...         NaN              1                   NaN
# 2         1  ...         NaN              1                   NaN
# 3         1  ...         NaN              1        010716BS07KA01
# 4         1  ...         NaN              1        010816BS08KA01
#
#   ECB Violation Numbers SWO  Permit  Permit No  Last Open Job  \
# 0                   NaN   0     NaN        NaN            NaN
# 1                   NaN   0     NaN        NaN            NaN
# 2                   NaN   1     NaN        NaN            NaN
# 3                   NaN   1     NaN        NaN            NaN
# 4                   NaN   1      NB  320626710            NaN
#
#    ContractorLicenseClass  Fatality Details
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Create smaller datasets from incidents data and permits (merged) data

# %%
#Create smaller datasets
incidents_df_2 = incidents_df[["BIN", "Incident date (MM/DD/YYYY)"]]
permits_df_2 = permits_df[["Bin", "Permit Issued Date", "Permit Expiration Date","Contractor Name","Permit Type","Permit Sub Type"]]

#Make sure BIN column is named the same way in both
permits_df_2 = permits_df_2.rename(columns={'Bin': 'BIN',},)

#Rename the Incident date col
incidents_df_2 = incidents_df_2.rename(columns={'Incident date (MM/DD/YYYY)': 'Incident Date',},)

display(incidents_df_2.head())
display(permits_df_2.head())
# Out:
#          BIN        Incident Date
# 0  1089709.0  2016-01-04 00:00:00
# 1  1081692.0  2016-01-05 00:00:00
# 2  1045576.0  2016-01-07 00:00:00
# 3  1030884.0  2016-01-07 00:00:00
# 4  3418188.0  2016-01-07 00:00:00
#        BIN Permit Issued Date Permit Expiration Date  \
# 0  1048918         2019-09-24             2020-12-31
# 1  1048918         2019-09-24             2020-09-23
# 2  1048918         2022-02-03             2023-02-03
# 3  1048918         2019-09-24             2020-12-31
# 4  1048918         2019-09-24             2020-09-23
#
#                  Contractor Name Permit Type Permit Sub Type
# 0  ANTHONY MORALI ARCHITECT PLLC          EW              OT
# 1  ANTHONY MORALI ARCHITECT PLLC          PL             NaN
# 2  ANTHONY MORALI ARCHITECT PLLC          PL             NaN
# 3        ROBERT STRONG ARCHITECT          EW              OT
# 4        ROBERT STRONG ARCHITECT          PL             NaN

# %% [markdown]
# ### Merge the datasets "incidents_df_2" and "permits_df_2"

# %%
print(len(incidents_df_2))
merged_dataset = pd.merge(incidents_df_2, permits_df_2, how='left', on="BIN")
print(len(merged_dataset))
merged_dataset.head()
# Out:
# 3607
# 369915
#          BIN        Incident Date Permit Issued Date Permit Expiration Date  \
# 0  1089709.0  2016-01-04 00:00:00         2015-09-10             2016-09-09
# 1  1089709.0  2016-01-04 00:00:00         2016-10-17             2017-10-17
# 2  1089709.0  2016-01-04 00:00:00         2018-04-04             2019-04-04
# 3  1089709.0  2016-01-04 00:00:00         2016-02-11             2017-02-10
# 4  1089709.0  2016-01-04 00:00:00         2015-12-31             2016-11-29
#
#             Contractor Name Permit Type Permit Sub Type
# 0  DAGHER ENGINEERING PLLC.          PL             NaN
# 1  DAGHER ENGINEERING PLLC.          PL             NaN
# 2  DAGHER ENGINEERING PLLC.          PL             NaN
# 3           SLCE ARCHITECTS          EQ              FN
# 4           SLCE ARCHITECTS          FO             NaN

# %% [markdown]
# ### Convert the Dates to datatime objects

# %%
merged_dataset['Incident Date'] = merged_dataset['Incident Date'].astype('datetime64[ns]')
merged_dataset['Permit Issued Date'] = merged_dataset['Permit Issued Date'].astype('datetime64[ns]')
merged_dataset['Permit Expiration Date'] = merged_dataset['Permit Expiration Date'].astype('datetime64[ns]')
merged_dataset.head()
# Out:
#          BIN Incident Date Permit Issued Date Permit Expiration Date  \
# 0  1089709.0    2016-01-04         2015-09-10             2016-09-09
# 1  1089709.0    2016-01-04         2016-10-17             2017-10-17
# 2  1089709.0    2016-01-04         2018-04-04             2019-04-04
# 3  1089709.0    2016-01-04         2016-02-11             2017-02-10
# 4  1089709.0    2016-01-04         2015-12-31             2016-11-29
#
#             Contractor Name Permit Type Permit Sub Type
# 0  DAGHER ENGINEERING PLLC.          PL             NaN
# 1  DAGHER ENGINEERING PLLC.          PL             NaN
# 2  DAGHER ENGINEERING PLLC.          PL             NaN
# 3           SLCE ARCHITECTS          EQ              FN
# 4           SLCE ARCHITECTS          FO             NaN

# %% [markdown]
# ### Create a column for flag

# %%
merged_dataset["Flag"] = 0
merged_dataset.head()
# Out:
#          BIN Incident Date Permit Issued Date Permit Expiration Date  \
# 0  1089709.0    2016-01-04         2015-09-10             2016-09-09
# 1  1089709.0    2016-01-04         2016-10-17             2017-10-17
# 2  1089709.0    2016-01-04         2018-04-04             2019-04-04
# 3  1089709.0    2016-01-04         2016-02-11             2017-02-10
# 4  1089709.0    2016-01-04         2015-12-31             2016-11-29
#
#             Contractor Name Permit Type Permit Sub Type  Flag
# 0  DAGHER ENGINEERING PLLC.          PL             NaN     0
# 1  DAGHER ENGINEERING PLLC.          PL             NaN     0
# 2  DAGHER ENGINEERING PLLC.          PL             NaN     0
# 3           SLCE ARCHITECTS          EQ              FN     0
# 4           SLCE ARCHITECTS          FO             NaN     0

# %%
#display the merged_dataset
merged_dataset
# Out:
#               BIN Incident Date Permit Issued Date Permit Expiration Date  \
# 0       1089709.0    2016-01-04         2015-09-10    2016-09-09 00:00:00
# 1       1089709.0    2016-01-04         2016-10-17    2017-10-17 00:00:00
# 2       1089709.0    2016-01-04         2018-04-04    2019-04-04 00:00:00
# 3       1089709.0    2016-01-04         2016-02-11    2017-02-10 00:00:00
# 4       1089709.0    2016-01-04         2015-12-31    2016-11-29 00:00:00
# ...           ...           ...                ...                    ...
# 369910  1034194.0    2022-02-22         2020-11-09    2021-07-12 04:00:00
# 369911  1034194.0    2022-02-22         2022-01-10    2022-06-30 00:00:00
# 369912  1034194.0    2022-02-22         2022-01-10    2022-06-30 00:00:00
# 369913  1034194.0    2022-02-22         2022-01-12    2022-06-30 00:00:00
# 369914  1034194.0    2022-02-22         2022-01-12    2022-06-30 00:00:00
#
#                  Contractor Name Permit Type Permit Sub Type  Flag
# 0       DAGHER ENGINEERING PLLC.          PL             NaN     0
# 1       DAGHER ENGINEERING PLLC.          PL             NaN     0
# 2       DAGHER ENGINEERING PLLC.          PL             NaN     0
# 3                SLCE ARCHITECTS          EQ              FN     0
# 4                SLCE ARCHITECTS          FO             NaN     0
# ...                          ...         ...             ...   ...
# 369910         KOHLER RONAN, LLC          EQ              SP     0
# 369911         KOHLER RONAN, LLC          EQ              PL     0
# 369912         KOHLER RONAN, LLC          EQ              SP     0
# 369913         KOHLER RONAN, LLC          EQ              PL     0
# 369914         KOHLER RONAN, LLC          EQ              SP     0
#
# [369915 rows x 8 columns]

# %%
# Download the merged_dataset file
merged_dataset.to_csv(path + "merged_dataset.csv", index=0)

# %% [markdown]
# ### If the incident occured while the permit was active, set flag to 1

# %%
for i in range(0,len(merged_dataset)):
    if (merged_dataset["Incident Date"][i] >= merged_dataset["Permit Issued Date"][i] and merged_dataset["Incident Date"][i] <= merged_dataset["Permit Expiration Date"][i]):
        merged_dataset["Flag"][i] = 1

merged_dataset.head()

# %%
##create dictionary for permits
merged_dataset["BIN"] =merged_dataset["BIN"].astype(str).replace('\.0', '', regex=True)

#copy the dataset into a new df called comp2_t
comp2_t = merged_dataset.copy()

#groupby the BIN and sum all
comp2_t = comp2_t.groupby(['BIN']).sum()

#this is adding an empty string to the end of column name strings
comp2_t = comp2_t.add_suffix('').reset_index()

#sort the BIN values
comp2_t = comp2_t.sort_values(by = 'BIN', ascending=True).reset_index(drop=True)

#make sure the BIN is a str type
comp2_t["BIN"] = comp2_t["BIN"].astype(str)

#set the key:value as BIN:Flag
permitDic = comp2_t.set_index('BIN')['Flag'].to_dict()

# permitDic

# %% [markdown]
# ### Contractor groupby

# %%
# Create a new dataframe called con with just two cols
con= merged_dataset[["BIN","Contractor Name","Flag"]]
print(len(con))
con = con[con["Flag"]==1]
con = con.reset_index(drop=True)
print(len(con))
#Drop nan values
con["Contractor Name"] = con["Contractor Name"].astype(str)
con["Contractor Name"] = con["Contractor Name"].replace('nan','')
con["Contractor Name"] = con["Contractor Name"].astype(str).map(str.strip)



#Convert to String

#drop duplicates code
con = con.groupby(['BIN'])['Contractor Name'].apply(', '.join).reset_index()
print(len(con))
con.head(10)

# %% [markdown]
# ### Permits groupby

# %%
# Create a new dataframe called permit_type with just two cols
permit_type= merged_dataset[["BIN","Permit Type","Flag"]]
print(len(permit_type))
permit_type = permit_type[permit_type["Flag"]==1]
permit_type = permit_type.reset_index(drop=True)
print(len(permit_type))
#Drop nan values
permit_type["Permit Type"] = permit_type["Permit Type"].astype(str)
permit_type["Permit Type"] = permit_type["Permit Type"].replace('nan','')
permit_type["Permit Type"] = permit_type["Permit Type"].astype(str).map(str.strip)


#Convert to String

#drop duplicates code
permit_type = permit_type.groupby(['BIN'])['Permit Type'].apply(', '.join).reset_index()
print(len(permit_type))
permit_type.head(10)

# %% [markdown]
# ### Permits Subtype groupby

# %%
# Create a new dataframe called permit_subtype with just two cols
permit_subtype= merged_dataset[["BIN","Permit Sub Type","Flag"]]
print(len(permit_subtype))
permit_subtype = permit_subtype[permit_subtype["Flag"]==1]
permit_subtype = permit_subtype.reset_index(drop=True)
print(len(permit_subtype))
#Drop nan values
permit_subtype["Permit Sub Type"] = permit_subtype["Permit Sub Type"].astype(str)
permit_subtype["Permit Sub Type"] = permit_subtype["Permit Sub Type"].replace('nan','')
permit_subtype["Permit Sub Type"] = permit_subtype["Permit Sub Type"].astype(str).map(str.strip)



#Convert to String

#drop duplicates code
permit_subtype = permit_subtype.groupby(['BIN'])['Permit Sub Type'].apply(', '.join).reset_index()
print(len(permit_subtype))
permit_subtype.head(10)

# %%
## Count Accident

# %%
incidents_df_3 = incidents_df[["BIN", "Accident"]]
incidents_df_3= incidents_df_3.groupby(['BIN'], as_index=False).count()
incidents_df_3.head()

# %%
#Deleting the decimal from the number
incidents_df_3["BIN"] =incidents_df_3["BIN"].astype(str).replace('\.0', '', regex=True)

incidents_df_3

# %% [markdown]
# ### Merge all the variables

# %%
incidents_df_3["Active Permits"] = incidents_df_3["BIN"].map(permitDic)
incidents_df_3 = incidents_df_3.merge(con,how='left',on='BIN')
incidents_df_3 = incidents_df_3.merge(permit_type,how='left',on='BIN')
incidents_df_3 = incidents_df_3.merge(permit_subtype,how='left',on='BIN')

incidents_df_3

# %%
incidents_df_3.head()

# %%
sb.displot(incidents_df_3['Accident'], kind="kde")

# %%
# This function will help to evaluate linear relationship for two variables

def evaluate_linear_relationship(a, b):
    slope = np.cov(a, b, bias=True)[0][1] / np.var(a)
    intercept = np.mean(b) - (slope * np.mean(a))
    predictions = (slope * a) + intercept
    residuals = b - predictions
    return slope, intercept, predictions, residuals

# This function will help evaluate the intervals when we reach Confidence Intervals and Predication Intervals part
def get_intervals(a, b, residuals):
    t = stats.t(df=len(a) - 2).ppf(0.975)
    s_err = np.sum(np.power(residuals, 2))
    confidence_interval = t * np.sqrt((s_err/(len(a) - 2))*(1/len(a) + (np.power((a - a.mean()), 2)/((np.sum(np.power(a,2))) - len(full_df)*(np.power(a.mean(),2))))))
    prediction_interval = t * (np.std(residuals))
    return abs(confidence_interval), prediction_interval

# %%
slope, intercept, predictions, residuals = evaluate_linear_relationship(incidents_df_3["Accident"], incidents_df_3['Active Permits'])

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(incidents_df_3["Accident"],incidents_df_3['Active Permits'])
sorted_order = np.argsort(incidents_df_3["Accident"])
plt.plot(incidents_df_3["Accident"][sorted_order], predictions[sorted_order])
plt.ylabel("Active Permits")
plt.xlabel('Accidents')
fig.suptitle("Relationship between Accidents and Active Permits", fontsize=15, y=0.92)

incidents_df_3[incidents_df_3['Accident'] == 35]

# %%
fig = plt.figure(figsize=(20,10))
plt.hist(incidents_df_3['Accident'], bins=50)
plt.xlabel("Accidents")
plt.ylabel("Frequency")
fig.suptitle("Accidents", fontsize=15, y=0.92)

# %%
fig, ax = plt.subplots(figsize=(16,10), dpi= 80)    
sns.stripplot(incidents_df_3["Accident"], incidents_df_3["Active Permits"], ax=ax)

# Decorations
plt.title('Counts Plot - Size of circle is bigger as more points overlap', fontsize=22)
plt.show()

# %% [markdown]
# ### View permits_df

# %%
permits_df.head(2)

# %% [markdown]
# ### Run groupby for Bin and Contractor Name

# %% [markdown]
# ### Run groupby for Bin and Permit Type

# %%
# Create a new dataframe called permits_df_4 with just two cols
permits_df_4= permits_df[["Bin","Permit Type"]]

#Drop nan values
permits_df_4 = permits_df_4[permits_df_4["Permit Type"]!='nan']

#Convert to String
permits_df_4['Permit Type'] = permits_df_4['Permit Type'].astype(str)

#drop duplicates code
permits_df_4 = permits_df_4.drop_duplicates(subset=['Bin','Permit Type'])
permits_df_4 = permits_df_4.groupby(['Bin'])['Permit Type'].apply(', '.join).reset_index()
permits_df_4.head(10)

# %%
merged_dataset.isna().sum()

# %%
permits_df.isna().sum()

# %%
permits_df.isnull().sum(axis=1)

# %%
permits_df_3["Bin"].value_counts()

# %%
permits_df_3["Bin"].dtypes

# %%
def missing_values_table(df):
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    return mis_val_table_ren_columns

# %%
missing_values_table(permits_df)
